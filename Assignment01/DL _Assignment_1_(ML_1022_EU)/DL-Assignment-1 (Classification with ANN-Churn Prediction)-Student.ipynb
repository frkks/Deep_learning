# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Assignment-1 (ANN)<br><br>Churn Prediction for Bank Customer<br><h1>

# %% [markdown]
# # Dataset Info

# %% [markdown]
# We have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.
#
# The features in the given dataset are:
# - **rownumber:** Row Numbers from 1 to 10000.
# - **customerid:** A unique ID that identifies each customer.
# - **surname:** The customer’s surname.
# - **creditscore:** A credit score is a number between 300–850 that depicts a consumer's creditworthiness.
# - **geography:** The country from which the customer belongs to.
# - **Gender:** The customer’s gender: Male, Female
# - **Age:** The customer’s current age, in years, at the time of being customer.
# - **tenure:** The number of years for which the customer has been with the bank.
# - **balance:** Bank balance of the customer.
# - **numofproducts:** the number of bank products the customer is utilising.
# - **hascrcard:** The number of credit cards given to the customer by the bank.
# - **isactivemember:** Binary Flag for indicating if the client is active or not with the bank before the moment where the client exits the company (recorded in the variable "exited")
# - **exited:** Binary flag 1 if the customer closed account with bank and 0 if the customer is retained.

# %% [markdown]
# # Improt Libraries & Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
df = pd.read_csv("Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.000              1          1               1
# 1       1  83807.860              1          0               1
# 2       8 159660.800              3          1               0
# 3       1      0.000              2          0               0
# 4       2 125510.820              1          1               1
#
#    EstimatedSalary  Exited
# 0       101348.880       1
# 1       112542.580       0
# 2       113931.570       1
# 3        93826.630       0
# 4        79084.100       0

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %% [markdown]
# 1. Implement basic steps to see how is your data looks like
# 2. Check for missing values
# 3. Drop the features that not suitable for modelling
# 4. Implement basic visualization steps such as histogram, countplot, heatmap
# 5. Convert categorical variables to dummy variables

# %%
df.info() # to know the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe().T # to see the summary of the dataframe
# Out:
#                     count         mean       std          min          25%  \
# RowNumber       10000.000     5000.500  2886.896        1.000     2500.750
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# RowNumber           5000.500     7500.250    10000.000
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
df.isnull().sum() # check for missing values
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum() # check for duplicate values
# Out:
# 0

# %%
# we didn't require customerID, Surname  and Rownumber so we drop it

df = df.drop(["CustomerId","RowNumber","Surname",],axis=1)

# %%
#numerical variables

num = list(df.select_dtypes(include=[np.number]).columns)

#categorical variables

cat = list(df.select_dtypes(include='object').columns)

print(cat)

print(num)
# Out:
# ['Geography', 'Gender']
# ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']

# %%
for i in cat:
    print(df[i].value_counts())
    print("------")
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
# ------
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
# ------

# %%
df.Exited.value_counts() # Target values
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
labels = 'Exited', 'Retained'
import random
n = 40
color = ["#" + ''.join([random.choice('0123456789ABCDEF')
                        for j in range(6)]) for i in range(n)]
plt.figure(figsize=(10,8))
explode = [0,0.1]
plt.pie(df['Exited'].value_counts(), labels=labels,explode=explode,autopct='%1.1f%%', colors=color, startangle=45)
plt.title('Churn Distribution');

# %%
 # We first review the 'Status' relation with categorical variables
fig, axarr = plt.subplots(2, 2, figsize=(20, 12))
sns.countplot(x='Geography', hue = 'Exited',data = df, ax=axarr[0][0])
sns.countplot(x='Gender', hue = 'Exited',data = df, ax=axarr[0][1])
sns.countplot(x='HasCrCard', hue = 'Exited',data = df, ax=axarr[1][0])
sns.countplot(x='IsActiveMember', hue = 'Exited',data = df, ax=axarr[1][1]);

# %%
ax = sns.countplot(x='Exited',data=df,hue='Gender')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1]);

# %%
ax = sns.countplot(x='Exited',data=df, hue='HasCrCard')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1]);

# %%
ax = sns.countplot(x='Exited',data=df, hue='Geography')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2]);

# %%
ax = sns.countplot(df["Tenure"]);
ax.bar_label(ax.containers[0]);

# %%
plt.figure(figsize=(16,6))
ax = sns.histplot(data=df, x="Age",bins=20, hue="Exited", kde=True);
ax.bar_label(ax.containers[0]);

# %%
plt.figure(figsize = (8,10))
df.corr()["Exited"].sort_values().drop("Exited").plot(kind = "barh")
ax.bar_label(ax.containers[0]);

# %%
plt.figure(figsize=(14, 10))

# Getting the Upper Triangle of the co-relation matrix
matrix = np.triu(df.corr())

# using the upper triangle matrix as mask 
sns.heatmap(df.corr(), annot=True, cmap = sns.cubehelix_palette(20), mask=matrix)

plt.xticks(rotation=45);

# %%
index = 0
plt.figure(figsize=(20,20))
for feature in num:
    if feature != "Exited":
        index += 1
        plt.subplot(4, 3, index)
        sns.boxplot(x='Exited', y=feature, data=df)

# %%
sns.pairplot(df, hue="Exited", corner=True);

# %%
sns.swarmplot(y="Age", x="Geography", hue="Exited", data=df);

# %%
sns.swarmplot(y="Age", x="Gender", hue="Exited", data=df);

# %%
df.insert(11, 'churn', df['Exited'])

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2      0.000              1
# 1          608     Spain  Female   41       1  83807.860              1
# 2          502    France  Female   42       8 159660.800              3
# 3          699    France  Female   39       1      0.000              2
# 4          850     Spain  Female   43       2 125510.820              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  churn
# 0          1               1       101348.880       1      1
# 1          0               1       112542.580       0      0
# 2          1               0       113931.570       1      1
# 3          0               0        93826.630       0      0
# 4          1               1        79084.100       0      0

# %%
df.drop('Exited', axis=1, inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2      0.000              1
# 1          608     Spain  Female   41       1  83807.860              1
# 2          502    France  Female   42       8 159660.800              3
# 3          699    France  Female   39       1      0.000              2
# 4          850     Spain  Female   43       2 125510.820              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  churn
# 0          1               1       101348.880      1
# 1          0               1       112542.580      0
# 2          1               0       113931.570      1
# 3          0               0        93826.630      0
# 4          1               1        79084.100      0

# %%
df = pd.get_dummies(df, drop_first =True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.000              1          1
# 1          608   41       1  83807.860              1          0
# 2          502   42       8 159660.800              3          1
# 3          699   39       1      0.000              2          0
# 4          850   43       2 125510.820              1          1
#
#    IsActiveMember  EstimatedSalary  churn  Geography_Germany  Geography_Spain  \
# 0               1       101348.880      1                  0                0
# 1               1       112542.580      0                  0                1
# 2               0       113931.570      1                  0                0
# 3               0        93826.630      0                  0                0
# 4               1        79084.100      0                  0                1
#
#    Gender_Male
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %% [markdown]
# # Preprocessing of Data
# - Train | Test Split, Scalling

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('churn', axis = 1)
y = df['churn']

# %%
seed = 21

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size=0.2, random_state=seed)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape)   
print(X_test.shape)
# Out:
# (8000, 11)
# (2000, 11)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000,)
# (2000,)

# %% [markdown]
# # Modelling & Model Performance

# %% [markdown]
# ## without class_weigth

# %% [markdown]
# ### Create The Model

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %% [markdown]
# ## with class_weigth
#
# Investigate how the "class_weight" hyper-parameter is used in a Neural Network.

# %% [markdown]
# ### Create The Model

# %%
# define sequential model

model = Sequential()
model.add(Dense(15, activation='relu',input_dim = X_train.shape[1]))
model.add(Dense(10, activation='relu'))
model.add(Dense(5,  activation = 'relu'))
model.add(Dense(1, activation='sigmoid')) # we use sigmoid for binary output
model.summary()


# compile the model

model.compile(optimizer = 'adam',loss = 'binary_crossentropy', metrics = ['accuracy'])

# early stopping 
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 20)

# now we fit our model to training data
model.fit(x = X_train, y = y_train, epochs=250, validation_split = 0.1, batch_size=32,verbose=1,callbacks = [early_stop])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                180
#
#  dense_1 (Dense)             (None, 10)                160
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.5316 - accuracy: 0.7876 - val_loss: 0.4801 - val_accuracy: 0.7975
# Epoch 2/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7968 - val_loss: 0.4588 - val_accuracy: 0.7975
# Epoch 3/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4646 - accuracy: 0.7989 - val_loss: 0.4378 - val_accuracy: 0.8125
# Epoch 4/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4524 - accuracy: 0.8067 - val_loss: 0.4226 - val_accuracy: 0.8213
# Epoch 5/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4444 - accuracy: 0.8115 - val_loss: 0.4162 - val_accuracy: 0.8188
# Epoch 6/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.8112 - val_loss: 0.4065 - val_accuracy: 0.8350
# Epoch 7/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.8121 - val_loss: 0.4046 - val_accuracy: 0.8413
# Epoch 8/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4342 - accuracy: 0.8129 - val_loss: 0.4022 - val_accuracy: 0.8413
# Epoch 9/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4340 - accuracy: 0.8117 - val_loss: 0.3999 - val_accuracy: 0.8388
# Epoch 10/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4315 - accuracy: 0.8133 - val_loss: 0.3987 - val_accuracy: 0.8388
# Epoch 11/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.8158 - val_loss: 0.3991 - val_accuracy: 0.8350
# Epoch 12/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4286 - accuracy: 0.8144 - val_loss: 0.3974 - val_accuracy: 0.8413
# Epoch 13/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.8165 - val_loss: 0.3985 - val_accuracy: 0.8338
# Epoch 14/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4250 - accuracy: 0.8206 - val_loss: 0.3917 - val_accuracy: 0.8413
# Epoch 15/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.8201 - val_loss: 0.3895 - val_accuracy: 0.8400
# Epoch 16/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.8221 - val_loss: 0.3880 - val_accuracy: 0.8462
# Epoch 17/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4164 - accuracy: 0.8246 - val_loss: 0.3890 - val_accuracy: 0.8400
# Epoch 18/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4123 - accuracy: 0.8256 - val_loss: 0.3823 - val_accuracy: 0.8512
# Epoch 19/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8281 - val_loss: 0.3833 - val_accuracy: 0.8388
# Epoch 20/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8321 - val_loss: 0.3755 - val_accuracy: 0.8413
# Epoch 21/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3924 - accuracy: 0.8356 - val_loss: 0.3663 - val_accuracy: 0.8612
# Epoch 22/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8406 - val_loss: 0.3561 - val_accuracy: 0.8650
# Epoch 23/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3740 - accuracy: 0.8422 - val_loss: 0.3497 - val_accuracy: 0.8625
# Epoch 24/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3669 - accuracy: 0.8483 - val_loss: 0.3493 - val_accuracy: 0.8637
# Epoch 25/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3630 - accuracy: 0.8487 - val_loss: 0.3465 - val_accuracy: 0.8675
# Epoch 26/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3600 - accuracy: 0.8493 - val_loss: 0.3406 - val_accuracy: 0.8737
# Epoch 27/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3583 - accuracy: 0.8504 - val_loss: 0.3390 - val_accuracy: 0.8700
# Epoch 28/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.8500 - val_loss: 0.3400 - val_accuracy: 0.8725
# Epoch 29/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3547 - accuracy: 0.8524 - val_loss: 0.3392 - val_accuracy: 0.8712
# Epoch 30/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3541 - accuracy: 0.8521 - val_loss: 0.3395 - val_accuracy: 0.8687
# Epoch 31/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3513 - accuracy: 0.8557 - val_loss: 0.3359 - val_accuracy: 0.8712
# Epoch 32/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.8529 - val_loss: 0.3387 - val_accuracy: 0.8712
# Epoch 33/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3502 - accuracy: 0.8543 - val_loss: 0.3341 - val_accuracy: 0.8763
# Epoch 34/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3495 - accuracy: 0.8556 - val_loss: 0.3336 - val_accuracy: 0.8687
# Epoch 35/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8537 - val_loss: 0.3322 - val_accuracy: 0.8700
# Epoch 36/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3483 - accuracy: 0.8544 - val_loss: 0.3345 - val_accuracy: 0.8675
# Epoch 37/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3472 - accuracy: 0.8539 - val_loss: 0.3321 - val_accuracy: 0.8725
# Epoch 38/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8558 - val_loss: 0.3312 - val_accuracy: 0.8712
# Epoch 39/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8547 - val_loss: 0.3316 - val_accuracy: 0.8712
# Epoch 40/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.8547 - val_loss: 0.3340 - val_accuracy: 0.8725
# Epoch 41/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3448 - accuracy: 0.8565 - val_loss: 0.3332 - val_accuracy: 0.8700
# Epoch 42/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8572 - val_loss: 0.3325 - val_accuracy: 0.8725
# Epoch 43/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3429 - accuracy: 0.8574 - val_loss: 0.3278 - val_accuracy: 0.8725
# Epoch 44/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3432 - accuracy: 0.8579 - val_loss: 0.3333 - val_accuracy: 0.8687
# Epoch 45/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3433 - accuracy: 0.8578 - val_loss: 0.3287 - val_accuracy: 0.8725
# Epoch 46/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8575 - val_loss: 0.3344 - val_accuracy: 0.8712
# Epoch 47/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8565 - val_loss: 0.3283 - val_accuracy: 0.8712
# Epoch 48/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8593 - val_loss: 0.3267 - val_accuracy: 0.8737
# Epoch 49/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8578 - val_loss: 0.3252 - val_accuracy: 0.8763
# Epoch 50/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.8590 - val_loss: 0.3260 - val_accuracy: 0.8750
# Epoch 51/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.8572 - val_loss: 0.3269 - val_accuracy: 0.8737
# Epoch 52/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8582 - val_loss: 0.3264 - val_accuracy: 0.8800
# Epoch 53/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.8589 - val_loss: 0.3264 - val_accuracy: 0.8737
# Epoch 54/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8586 - val_loss: 0.3267 - val_accuracy: 0.8712
# Epoch 55/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8587 - val_loss: 0.3287 - val_accuracy: 0.8725
# Epoch 56/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8608 - val_loss: 0.3257 - val_accuracy: 0.8737
# Epoch 57/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.8582 - val_loss: 0.3270 - val_accuracy: 0.8712
# Epoch 58/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.8586 - val_loss: 0.3256 - val_accuracy: 0.8763
# Epoch 59/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8581 - val_loss: 0.3363 - val_accuracy: 0.8700
# Epoch 60/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.8611 - val_loss: 0.3257 - val_accuracy: 0.8725
# Epoch 61/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8603 - val_loss: 0.3262 - val_accuracy: 0.8725
# Epoch 62/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8594 - val_loss: 0.3346 - val_accuracy: 0.8712
# Epoch 63/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3370 - accuracy: 0.8597 - val_loss: 0.3239 - val_accuracy: 0.8750
# Epoch 64/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8581 - val_loss: 0.3249 - val_accuracy: 0.8775
# Epoch 65/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8608 - val_loss: 0.3229 - val_accuracy: 0.8750
# Epoch 66/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3373 - accuracy: 0.8617 - val_loss: 0.3240 - val_accuracy: 0.8763
# Epoch 67/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3368 - accuracy: 0.8578 - val_loss: 0.3244 - val_accuracy: 0.8763
# Epoch 68/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8604 - val_loss: 0.3248 - val_accuracy: 0.8775
# Epoch 69/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8596 - val_loss: 0.3242 - val_accuracy: 0.8737
# Epoch 70/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3362 - accuracy: 0.8639 - val_loss: 0.3224 - val_accuracy: 0.8750
# Epoch 71/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8603 - val_loss: 0.3248 - val_accuracy: 0.8725
# Epoch 72/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8606 - val_loss: 0.3234 - val_accuracy: 0.8788
# Epoch 73/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.8608 - val_loss: 0.3258 - val_accuracy: 0.8737
# Epoch 74/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8610 - val_loss: 0.3216 - val_accuracy: 0.8788
# Epoch 75/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3353 - accuracy: 0.8614 - val_loss: 0.3226 - val_accuracy: 0.8763
# Epoch 76/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8610 - val_loss: 0.3229 - val_accuracy: 0.8763
# Epoch 77/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.8599 - val_loss: 0.3259 - val_accuracy: 0.8763
# Epoch 78/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3353 - accuracy: 0.8596 - val_loss: 0.3211 - val_accuracy: 0.8788
# Epoch 79/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8617 - val_loss: 0.3231 - val_accuracy: 0.8788
# Epoch 80/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8596 - val_loss: 0.3223 - val_accuracy: 0.8737
# Epoch 81/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8604 - val_loss: 0.3248 - val_accuracy: 0.8763
# Epoch 82/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8596 - val_loss: 0.3213 - val_accuracy: 0.8763
# Epoch 83/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8617 - val_loss: 0.3265 - val_accuracy: 0.8737
# Epoch 84/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8614 - val_loss: 0.3220 - val_accuracy: 0.8800
# Epoch 85/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8596 - val_loss: 0.3233 - val_accuracy: 0.8788
# Epoch 86/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8629 - val_loss: 0.3227 - val_accuracy: 0.8763
# Epoch 87/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8612 - val_loss: 0.3213 - val_accuracy: 0.8775
# Epoch 88/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3335 - accuracy: 0.8643 - val_loss: 0.3232 - val_accuracy: 0.8763
# Epoch 89/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8621 - val_loss: 0.3222 - val_accuracy: 0.8850
# Epoch 90/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8614 - val_loss: 0.3259 - val_accuracy: 0.8763
# Epoch 91/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3326 - accuracy: 0.8612 - val_loss: 0.3241 - val_accuracy: 0.8775
# Epoch 92/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3319 - accuracy: 0.8621 - val_loss: 0.3274 - val_accuracy: 0.8700
# Epoch 93/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8619 - val_loss: 0.3252 - val_accuracy: 0.8725
# Epoch 94/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3328 - accuracy: 0.8625 - val_loss: 0.3222 - val_accuracy: 0.8825
# Epoch 95/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8631 - val_loss: 0.3224 - val_accuracy: 0.8775
# Epoch 96/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3319 - accuracy: 0.8653 - val_loss: 0.3284 - val_accuracy: 0.8800
# Epoch 97/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8610 - val_loss: 0.3220 - val_accuracy: 0.8750
# Epoch 98/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3315 - accuracy: 0.8639 - val_loss: 0.3229 - val_accuracy: 0.8763
# Epoch 98: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                180
#
#  dense_1 (Dense)             (None, 10)                160
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    loss  accuracy  val_loss  val_accuracy
# 0 0.532     0.788     0.480         0.798
# 1 0.479     0.797     0.459         0.798
# 2 0.465     0.799     0.438         0.812
# 3 0.452     0.807     0.423         0.821
# 4 0.444     0.812     0.416         0.819

# %%
loss_df.plot();

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %%
model.evaluate(X_test,y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3252 - accuracy: 0.8670
# [0.3251543939113617, 0.8669999837875366]

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.3251543939113617
# accuracy :  0.8669999837875366

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[1523   70]
#  [ 196  211]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      1593
#            1       0.75      0.52      0.61       407
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.74      0.77      2000
# weighted avg       0.86      0.87      0.86      2000

# %% [markdown]
# ## Implementation Different Methods to Develop The Model
#
# - Implement the following methods on model creating with "class_weight" parameter
# - Create and evaluate model for each method

# %% [markdown]
# ### Increase The Learning Rate and Observe The Results

# %%
from sklearn.utils import class_weight

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 classes= np.unique(y_train),
                                                 y = y_train)

# %%
class_weights
# Out:
# array([0.62794349, 2.45398773])

# %%
# define sequential model

model_weighted  = Sequential()
model_weighted .add(Dense(15, activation='relu',input_dim = X_train.shape[1]))
model_weighted .add(Dense(10, activation='relu'))
model_weighted .add(Dense(5,  activation = 'relu'))
model_weighted .add(Dense(1, activation='sigmoid')) # we use sigmoid for binary output
model_weighted .summary()


# compile the model
opt = Adam(lr = 0.005)

model_weighted .compile(optimizer = opt, loss = 'binary_crossentropy',metrics = ['accuracy'])

# early stopping 
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 20)

# now we fit our model to training data

class_weight = {0:0.62794349 , 1:2.45398773}

model_weighted .fit(x=X_train, y=y_train, epochs=250, batch_size=32, validation_split = 0.1, verbose=1, class_weight=class_weight,
          callbacks = [early_stop])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 15)                180
#
#  dense_5 (Dense)             (None, 10)                160
#
#  dense_6 (Dense)             (None, 5)                 55
#
#  dense_7 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.6362 - accuracy: 0.6574 - val_loss: 0.6592 - val_accuracy: 0.6037
# Epoch 2/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5729 - accuracy: 0.7018 - val_loss: 0.5271 - val_accuracy: 0.7437
# Epoch 3/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5237 - accuracy: 0.7469 - val_loss: 0.4866 - val_accuracy: 0.7688
# Epoch 4/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5105 - accuracy: 0.7588 - val_loss: 0.4567 - val_accuracy: 0.7688
# Epoch 5/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.5013 - accuracy: 0.7575 - val_loss: 0.4809 - val_accuracy: 0.7487
# Epoch 6/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4976 - accuracy: 0.7565 - val_loss: 0.4593 - val_accuracy: 0.7713
# Epoch 7/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4946 - accuracy: 0.7649 - val_loss: 0.4853 - val_accuracy: 0.7400
# Epoch 8/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4887 - accuracy: 0.7615 - val_loss: 0.4990 - val_accuracy: 0.7525
# Epoch 9/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4868 - accuracy: 0.7628 - val_loss: 0.4234 - val_accuracy: 0.8075
# Epoch 10/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4847 - accuracy: 0.7651 - val_loss: 0.4678 - val_accuracy: 0.7600
# Epoch 11/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4825 - accuracy: 0.7619 - val_loss: 0.4441 - val_accuracy: 0.7850
# Epoch 12/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4778 - accuracy: 0.7681 - val_loss: 0.4214 - val_accuracy: 0.8075
# Epoch 13/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4765 - accuracy: 0.7658 - val_loss: 0.4547 - val_accuracy: 0.7775
# Epoch 14/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4752 - accuracy: 0.7692 - val_loss: 0.3782 - val_accuracy: 0.8375
# Epoch 15/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4705 - accuracy: 0.7683 - val_loss: 0.4515 - val_accuracy: 0.7925
# Epoch 16/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4721 - accuracy: 0.7721 - val_loss: 0.4500 - val_accuracy: 0.7862
# Epoch 17/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4713 - accuracy: 0.7696 - val_loss: 0.4228 - val_accuracy: 0.8012
# Epoch 18/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.7606 - val_loss: 0.4734 - val_accuracy: 0.7887
# Epoch 19/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4693 - accuracy: 0.7715 - val_loss: 0.4321 - val_accuracy: 0.7950
# Epoch 20/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4691 - accuracy: 0.7711 - val_loss: 0.4161 - val_accuracy: 0.8025
# Epoch 21/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4673 - accuracy: 0.7731 - val_loss: 0.4274 - val_accuracy: 0.7937
# Epoch 22/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4659 - accuracy: 0.7754 - val_loss: 0.3784 - val_accuracy: 0.8438
# Epoch 23/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4672 - accuracy: 0.7750 - val_loss: 0.4221 - val_accuracy: 0.8037
# Epoch 24/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4621 - accuracy: 0.7765 - val_loss: 0.4164 - val_accuracy: 0.8025
# Epoch 25/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.7739 - val_loss: 0.4664 - val_accuracy: 0.7700
# Epoch 26/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.7775 - val_loss: 0.4022 - val_accuracy: 0.8238
# Epoch 27/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.7744 - val_loss: 0.4277 - val_accuracy: 0.7962
# Epoch 28/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4613 - accuracy: 0.7790 - val_loss: 0.4643 - val_accuracy: 0.7525
# Epoch 29/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.7717 - val_loss: 0.4968 - val_accuracy: 0.7638
# Epoch 30/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4604 - accuracy: 0.7796 - val_loss: 0.3925 - val_accuracy: 0.8188
# Epoch 31/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4596 - accuracy: 0.7743 - val_loss: 0.4264 - val_accuracy: 0.8200
# Epoch 32/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4607 - accuracy: 0.7765 - val_loss: 0.4278 - val_accuracy: 0.7912
# Epoch 33/250
# 225/225 [==============================] - 1s 2ms/step - loss: 0.4597 - accuracy: 0.7757 - val_loss: 0.4332 - val_accuracy: 0.7850
# Epoch 34/250
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4604 - accuracy: 0.7796 - val_loss: 0.5322 - val_accuracy: 0.7225
# Epoch 34: early stopping

# %%
loss_df = pd.DataFrame(model_weighted .history.history)
loss_df.head()
# Out:
#    loss  accuracy  val_loss  val_accuracy
# 0 0.636     0.657     0.659         0.604
# 1 0.573     0.702     0.527         0.744
# 2 0.524     0.747     0.487         0.769
# 3 0.510     0.759     0.457         0.769
# 4 0.501     0.757     0.481         0.749

# %% [markdown]
# ### Add Dropout Layer

# %%
loss_df.plot();

# %% [markdown]
# ### Add Early Stop

# %% [markdown]
# #### Monitor the "val_loss" as metric

# %%
model_weighted .evaluate(X_test, y_test, verbose=0)
# Out:
# [0.5489886403083801, 0.7225000262260437]

# %%
loss, accuracy = model_weighted.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.5489886403083801
# accuracy :  0.7225000262260437

# %% [markdown]
# #### Monitor the "val_recall" as metric

# %%
y_pred = (model_weighted.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 938us/step
# [[1100  493]
#  [  62  345]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.69      0.80      1593
#            1       0.41      0.85      0.55       407
#
#     accuracy                           0.72      2000
#    macro avg       0.68      0.77      0.68      2000
# weighted avg       0.84      0.72      0.75      2000

# %% [markdown]
# ## GridSearchCV

# %%
def build_classifier(optimizer, learn_rate):
    classifier = Sequential()
    classifier.add(Dense(units = 15, activation = 'relu'))
    classifier.add(Dense(units = 10, activation = 'relu'))
    classifier.add(Dense(units = 5, activation = 'relu'))
    classifier.add(Dense(units = 1, activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer(learn_rate), loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
early_stop = EarlyStopping(monitor = "val_accuracy", mode = "auto", verbose = 1, patience = 15)

# %%
tf.random.set_seed(seed)

classifier_model = KerasClassifier(build_fn = build_classifier, validation_split = 0.1, epochs = 200)

parameters = {'batch_size': [32, 64],
              'optimizer': [Adam, RMSprop, Adadelta, Nadam],
              'learn_rate': [0.001, 0.003, 0.005]}

grid_model = GridSearchCV(estimator = classifier_model,
                          param_grid = parameters,
                          scoring = 'accuracy',
                          cv = 10,
                          n_jobs = -1,
                          verbose = 1)
grid_model.fit(X_train, y_train, callbacks = [early_stop])
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# Epoch 1/200
# 113/113 [==============================] - 1s 3ms/step - loss: 0.5278 - accuracy: 0.7753 - val_loss: 0.4728 - val_accuracy: 0.7975
# Epoch 2/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.7993 - val_loss: 0.4293 - val_accuracy: 0.8188
# Epoch 3/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.4182 - accuracy: 0.8167 - val_loss: 0.3791 - val_accuracy: 0.8400
# Epoch 4/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8290 - val_loss: 0.3673 - val_accuracy: 0.8575
# Epoch 5/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3837 - accuracy: 0.8369 - val_loss: 0.3620 - val_accuracy: 0.8525
# Epoch 6/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8428 - val_loss: 0.3564 - val_accuracy: 0.8575
# Epoch 7/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3668 - accuracy: 0.8411 - val_loss: 0.3484 - val_accuracy: 0.8575
# Epoch 8/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8446 - val_loss: 0.3433 - val_accuracy: 0.8625
# Epoch 9/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.8454 - val_loss: 0.3550 - val_accuracy: 0.8637
# Epoch 10/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3588 - accuracy: 0.8462 - val_loss: 0.3403 - val_accuracy: 0.8637
# Epoch 11/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8479 - val_loss: 0.3398 - val_accuracy: 0.8612
# Epoch 12/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3576 - accuracy: 0.8494 - val_loss: 0.3387 - val_accuracy: 0.8687
# Epoch 13/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3576 - accuracy: 0.8497 - val_loss: 0.3567 - val_accuracy: 0.8600
# Epoch 14/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8486 - val_loss: 0.3631 - val_accuracy: 0.8587
# Epoch 15/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3567 - accuracy: 0.8494 - val_loss: 0.3346 - val_accuracy: 0.8687
# Epoch 16/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.8510 - val_loss: 0.3366 - val_accuracy: 0.8650
# Epoch 17/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3524 - accuracy: 0.8514 - val_loss: 0.3322 - val_accuracy: 0.8725
# Epoch 18/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.8518 - val_loss: 0.3315 - val_accuracy: 0.8712
# Epoch 19/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3499 - accuracy: 0.8539 - val_loss: 0.3306 - val_accuracy: 0.8687
# Epoch 20/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8564 - val_loss: 0.3341 - val_accuracy: 0.8700
# Epoch 21/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8542 - val_loss: 0.3370 - val_accuracy: 0.8625
# Epoch 22/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3479 - accuracy: 0.8560 - val_loss: 0.3299 - val_accuracy: 0.8712
# Epoch 23/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8561 - val_loss: 0.3269 - val_accuracy: 0.8700
# Epoch 24/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8547 - val_loss: 0.3298 - val_accuracy: 0.8725
# Epoch 25/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.8544 - val_loss: 0.3262 - val_accuracy: 0.8725
# Epoch 26/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.8569 - val_loss: 0.3264 - val_accuracy: 0.8725
# Epoch 27/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8551 - val_loss: 0.3312 - val_accuracy: 0.8675
# Epoch 28/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8560 - val_loss: 0.3265 - val_accuracy: 0.8725
# Epoch 29/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.8575 - val_loss: 0.3304 - val_accuracy: 0.8637
# Epoch 30/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8578 - val_loss: 0.3270 - val_accuracy: 0.8763
# Epoch 31/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.8611 - val_loss: 0.3251 - val_accuracy: 0.8737
# Epoch 32/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.8593 - val_loss: 0.3269 - val_accuracy: 0.8700
# Epoch 33/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3397 - accuracy: 0.8596 - val_loss: 0.3298 - val_accuracy: 0.8687
# Epoch 34/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.8579 - val_loss: 0.3313 - val_accuracy: 0.8675
# Epoch 35/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8594 - val_loss: 0.3323 - val_accuracy: 0.8612
# Epoch 36/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8594 - val_loss: 0.3281 - val_accuracy: 0.8712
# Epoch 37/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8568 - val_loss: 0.3300 - val_accuracy: 0.8675
# Epoch 38/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.8597 - val_loss: 0.3219 - val_accuracy: 0.8700
# Epoch 39/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3385 - accuracy: 0.8579 - val_loss: 0.3263 - val_accuracy: 0.8725
# Epoch 40/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3362 - accuracy: 0.8601 - val_loss: 0.3250 - val_accuracy: 0.8675
# Epoch 41/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3371 - accuracy: 0.8601 - val_loss: 0.3179 - val_accuracy: 0.8712
# Epoch 42/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8578 - val_loss: 0.3234 - val_accuracy: 0.8725
# Epoch 43/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.8599 - val_loss: 0.3225 - val_accuracy: 0.8687
# Epoch 44/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8617 - val_loss: 0.3305 - val_accuracy: 0.8675
# Epoch 45/200
# 113/113 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8614 - val_loss: 0.3174 - val_accuracy: 0.8712
# Epoch 45: early stopping
# GridSearchCV(cv=10,
#              estimator=<keras.wrappers.scikit_learn.KerasClassifier object at 0x00000242A6844B50>,
#              n_jobs=-1,
#              param_grid={'batch_size': [32, 64],
#                          'learn_rate': [0.001, 0.003, 0.005],
#                          'optimizer': [<class 'keras.optimizers.optimizer_v2.adam.Adam'>,
#                                        <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>,
#                                        <class 'keras.optimizers.optimizer_v2.adadelta.Adadelta'>,
#                                        <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>]},
#              scoring='accuracy', verbose=1)

# %%
grid_model.best_score_
# Out:
# 0.8571250000000001

# %%
grid_model.best_params_
# Out:
# {'batch_size': 64,
#  'learn_rate': 0.003,
#  'optimizer': keras.optimizers.optimizer_v2.adam.Adam}

# %%
grid_result = pd.DataFrame(grid_model.cv_results_)[["mean_test_score", "std_test_score", "rank_test_score", "params"]].sort_values(by='rank_test_score')
grid_result
# Out:
#     mean_test_score  std_test_score  rank_test_score  \
# 16            0.857           0.014                1
# 20            0.857           0.013                2
# 8             0.856           0.012                3
# 0             0.856           0.013                4
# 4             0.855           0.018                5
# 19            0.855           0.010                6
# 23            0.855           0.016                6
# 15            0.854           0.012                8
# 3             0.854           0.012                9
# 7             0.853           0.014               10
# 5             0.853           0.014               11
# 12            0.853           0.012               12
# 11            0.852           0.016               13
# 17            0.851           0.012               14
# 9             0.850           0.016               15
# 21            0.849           0.012               16
# 13            0.849           0.011               17
# 1             0.849           0.014               18
# 2             0.797           0.014               19
# 10            0.796           0.015               20
# 22            0.796           0.015               20
# 6             0.796           0.015               20
# 14            0.794           0.014               23
# 18            0.733           0.183               24
#
#                                                params
# 16  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 20  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 8   {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 0   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 4   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 19  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 23  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 15  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 3   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 7   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 5   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 12  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 11  {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 17  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 9   {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 21  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 13  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 1   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 2   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 10  {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 22  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 6   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 14  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 18  {'batch_size': 64, 'learn_rate': 0.003, 'optim...

# %%
y_pred = (grid_model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[1530   63]
#  [ 194  213]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      1593
#            1       0.77      0.52      0.62       407
#
#     accuracy                           0.87      2000
#    macro avg       0.83      0.74      0.77      2000
# weighted avg       0.86      0.87      0.86      2000

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %% [markdown]
# #### The Evaluation of ROC and AUC for Model without "class_weigth"

# %%
y_pred_proba = model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('False Positive Rates')
plt.ylabel('True Positive Rates')
plt.title('ROC Curve for Keras Model')
plt.show()
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.8707598199123623

# %% [markdown]
# #### The Evaluation of ROC and AUC for Model with "class_weigth"

# %%
y_pred_proba = grid_model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Grid Model')
plt.show()
# Out:
# 63/63 [==============================] - 0s 952us/step

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.8688719536177164

# %% [markdown]
# #### The Evaluation of ROC and AUC for GridsearchCV Model"

# %%
y_pred_proba = grid_model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Grid Model')
plt.show()
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.8688719536177164

# %% [markdown]
# # Final Model and Model Deployment

# %%
import pickle

pickle.dump(scaler, open("scaler_churn", 'wb'))

# %%
final_model  = Sequential()
final_model.add(Dense(15, activation='relu',input_dim = X_train.shape[1]))
final_model.add(Dense(10, activation='relu'))
final_model.add(Dense(5,  activation = 'relu'))
final_model.add(Dense(1, activation='sigmoid'))
final_model.summary()


# compile the model
opt = Adam(lr = 0.005)

final_model.compile(optimizer = opt, loss = 'binary_crossentropy',metrics = ['accuracy'])

# early stopping 
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 20)

# now we fit our model to training data

class_weight = {0:0.62794349 , 1:2.45398773}

final_model.fit(x=X_train, y=y_train, epochs=250, batch_size=32, validation_data = (X_test, y_test), verbose=1,
                    class_weight=class_weight,
                    callbacks = [early_stop])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 15)                180
#
#  dense_13 (Dense)            (None, 10)                160
#
#  dense_14 (Dense)            (None, 5)                 55
#
#  dense_15 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6417 - accuracy: 0.6641 - val_loss: 0.5637 - val_accuracy: 0.7300
# Epoch 2/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7206 - val_loss: 0.4550 - val_accuracy: 0.7880
# Epoch 3/250
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5105 - accuracy: 0.7516 - val_loss: 0.4525 - val_accuracy: 0.7915
# Epoch 4/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4984 - accuracy: 0.7607 - val_loss: 0.4172 - val_accuracy: 0.8060
# Epoch 5/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4933 - accuracy: 0.7682 - val_loss: 0.5110 - val_accuracy: 0.7540
# Epoch 6/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4878 - accuracy: 0.7671 - val_loss: 0.5432 - val_accuracy: 0.7290
# Epoch 7/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4828 - accuracy: 0.7720 - val_loss: 0.4254 - val_accuracy: 0.8120
# Epoch 8/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4824 - accuracy: 0.7753 - val_loss: 0.4731 - val_accuracy: 0.7770
# Epoch 9/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4825 - accuracy: 0.7751 - val_loss: 0.4565 - val_accuracy: 0.7890
# Epoch 10/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4764 - accuracy: 0.7778 - val_loss: 0.4990 - val_accuracy: 0.7475
# Epoch 11/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4756 - accuracy: 0.7764 - val_loss: 0.4076 - val_accuracy: 0.8245
# Epoch 12/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4769 - accuracy: 0.7763 - val_loss: 0.5391 - val_accuracy: 0.7310
# Epoch 13/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4723 - accuracy: 0.7790 - val_loss: 0.4093 - val_accuracy: 0.8140
# Epoch 14/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4715 - accuracy: 0.7770 - val_loss: 0.3800 - val_accuracy: 0.8385
# Epoch 15/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4708 - accuracy: 0.7744 - val_loss: 0.4362 - val_accuracy: 0.7980
# Epoch 16/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4665 - accuracy: 0.7782 - val_loss: 0.4537 - val_accuracy: 0.7900
# Epoch 17/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4693 - accuracy: 0.7759 - val_loss: 0.4043 - val_accuracy: 0.8205
# Epoch 18/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4684 - accuracy: 0.7854 - val_loss: 0.4855 - val_accuracy: 0.7700
# Epoch 19/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4694 - accuracy: 0.7721 - val_loss: 0.4666 - val_accuracy: 0.7940
# Epoch 20/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4645 - accuracy: 0.7832 - val_loss: 0.4061 - val_accuracy: 0.8200
# Epoch 21/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4626 - accuracy: 0.7868 - val_loss: 0.4566 - val_accuracy: 0.8010
# Epoch 22/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4642 - accuracy: 0.7804 - val_loss: 0.4458 - val_accuracy: 0.8040
# Epoch 23/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4614 - accuracy: 0.7849 - val_loss: 0.4450 - val_accuracy: 0.7920
# Epoch 24/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4619 - accuracy: 0.7847 - val_loss: 0.4285 - val_accuracy: 0.8075
# Epoch 25/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4617 - accuracy: 0.7869 - val_loss: 0.4361 - val_accuracy: 0.8105
# Epoch 26/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4589 - accuracy: 0.7904 - val_loss: 0.3810 - val_accuracy: 0.8330
# Epoch 27/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4602 - accuracy: 0.7846 - val_loss: 0.4347 - val_accuracy: 0.8055
# Epoch 28/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4588 - accuracy: 0.7855 - val_loss: 0.4539 - val_accuracy: 0.8025
# Epoch 29/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4553 - accuracy: 0.7926 - val_loss: 0.3909 - val_accuracy: 0.8345
# Epoch 30/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4601 - accuracy: 0.7922 - val_loss: 0.4187 - val_accuracy: 0.8290
# Epoch 31/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4527 - accuracy: 0.7950 - val_loss: 0.4740 - val_accuracy: 0.7825
# Epoch 32/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4538 - accuracy: 0.7903 - val_loss: 0.5278 - val_accuracy: 0.7595
# Epoch 33/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4549 - accuracy: 0.7955 - val_loss: 0.5412 - val_accuracy: 0.7500
# Epoch 34/250
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4549 - accuracy: 0.7931 - val_loss: 0.4285 - val_accuracy: 0.8115
# Epoch 34: early stopping

# %%
loss_df = pd.DataFrame(final_model.history.history)

loss_df.plot();

# %%
y_pred = (final_model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[1327  266]
#  [ 111  296]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88      1593
#            1       0.53      0.73      0.61       407
#
#     accuracy                           0.81      2000
#    macro avg       0.72      0.78      0.74      2000
# weighted avg       0.84      0.81      0.82      2000

# %%
model.save('model_churn.h5')

# %% [markdown]
# ### Loading Model and Scaler

# %%
from tensorflow.keras.models import load_model

# %%
model_churn = load_model('model_churn.h5')

scaler_churn = pickle.load(open("scaler_churn", "rb"))

# %% [markdown]
# ## Prediction

# %%
random_ten_customer = df.drop('churn', axis = 1).sample(n=10, random_state=101).iloc[0:10, :]

random_ten_customer
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 6676          619   52       8      0.000              2          1
# 6421          616   23       8  73112.950              1          1
# 9834          516   46       6  62212.290              1          0
# 8492          494   28       9 114731.760              2          0
# 9982          655   46       7 137145.120              1          1
# 8844          695   35       7      0.000              2          1
# 7247          582   40       3 110150.430              1          1
# 5862          682   40       4      0.000              2          1
# 3662          632   28       5 118890.810              1          0
# 3457          657   36       8 188241.050              2          0
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 6676               1       123242.110                  0                1
# 6421               1        62733.050                  0                0
# 9834               1       171681.860                  0                0
# 8492               1        79479.740                  0                0
# 9982               0       115146.400                  1                0
# 8844               0       160387.980                  0                1
# 7247               1       191757.650                  1                0
# 5862               1       140745.910                  0                0
# 3662               1       145157.970                  0                0
# 3457               0       183058.510                  0                1
#
#       Gender_Male
# 6676            1
# 6421            1
# 9834            0
# 8492            1
# 9982            0
# 8844            1
# 7247            0
# 5862            1
# 3662            0
# 3457            1

# %%
random_ten_customer = scaler_churn.transform(random_ten_customer)

random_ten_customer
# Out:
# array([[0.538     , 0.45945946, 0.8       , 0.        , 0.33333333,
#         1.        , 1.        , 0.6162115 , 0.        , 1.        ,
#         1.        ],
#        [0.532     , 0.06756757, 0.8       , 0.29140497, 0.        ,
#         1.        , 1.        , 0.3136373 , 0.        , 0.        ,
#         1.        ],
#        [0.332     , 0.37837838, 0.6       , 0.2479584 , 0.        ,
#         0.        , 1.        , 0.85843338, 0.        , 0.        ,
#         0.        ],
#        [0.288     , 0.13513514, 0.9       , 0.45728431, 0.33333333,
#         0.        , 1.        , 0.39737875, 0.        , 0.        ,
#         1.        ],
#        [0.61      , 0.37837838, 0.7       , 0.54661684, 0.        ,
#         1.        , 0.        , 0.57572908, 1.        , 0.        ,
#         0.        ],
#        [0.69      , 0.22972973, 0.7       , 0.        , 0.33333333,
#         1.        , 0.        , 0.80195859, 0.        , 1.        ,
#         1.        ],
#        [0.464     , 0.2972973 , 0.3       , 0.43902459, 0.        ,
#         1.        , 1.        , 0.95882192, 1.        , 0.        ,
#         0.        ],
#        [0.664     , 0.2972973 , 0.4       , 0.        , 0.33333333,
#         1.        , 1.        , 0.70373886, 0.        , 0.        ,
#         1.        ],
#        [0.564     , 0.13513514, 0.5       , 0.47386096, 0.        ,
#         0.        , 1.        , 0.72580126, 0.        , 0.        ,
#         0.        ],
#        [0.614     , 0.24324324, 0.8       , 0.75026896, 0.33333333,
#         0.        , 0.        , 0.91532206, 0.        , 1.        ,
#         1.        ]])

# %%
prediction = pd.DataFrame(model_churn.predict(random_ten_customer) > 0.5, columns=['prediction']).astype("int32")
prediction
# Out:
# 1/1 [==============================] - 0s 54ms/step
#    prediction
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# 5           0
# 6           0
# 7           0
# 8           0
# 9           0

# %%
actual = pd.DataFrame(df.sample(n=10, random_state=101)["churn"]).rename({'churn': 'actual'}, axis=1).astype("int32")
actual
# Out:
#       actual
# 6676       0
# 6421       0
# 9834       1
# 8492       0
# 9982       1
# 8844       0
# 7247       1
# 5862       0
# 3662       0
# 3457       1

# %%
pred_df = actual.join(prediction.set_index(actual.index))

pred_df
# Out:
#       actual  prediction
# 6676       0           0
# 6421       0           0
# 9834       1           0
# 8492       0           0
# 9982       1           1
# 8844       0           0
# 7247       1           0
# 5862       0           0
# 3662       0           0
# 3457       1           0

# %%
pred_df['prediction_accuracy'] = pred_df.apply(lambda x: "Correct Pred" if int(x['actual'] == x['prediction']) else "Wrong Pred", axis=1)

pred_df
# Out:
#       actual  prediction prediction_accuracy
# 6676       0           0        Correct Pred
# 6421       0           0        Correct Pred
# 9834       1           0          Wrong Pred
# 8492       0           0        Correct Pred
# 9982       1           1        Correct Pred
# 8844       0           0        Correct Pred
# 7247       1           0          Wrong Pred
# 5862       0           0        Correct Pred
# 3662       0           0        Correct Pred
# 3457       1           0          Wrong Pred

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
